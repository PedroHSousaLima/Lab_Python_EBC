# %%
import pyautogui as pag
import pyperclip as pc
import time
from datetime import datetime

pag.PAUSE = 1
agrd_crt = 3
agrd_med = 30

h1 = datetime.today()
dd1 = h1.strftime('%d-%m-%Y  %H:%M:%S')
print(f'Início da tratativa dos dados: {dd1}\n')


time.sleep(agrd_crt)
time.sleep(agrd_crt)

def easymedia_exe():
    pag.hotkey('win', 'r')
    pc.copy('C:\IBOPE\EasyMedia 4\esm.EasyMedia4.exe')
    pag.hotkey('ctrl', 'v')
    pag.press('enter')

easymedia_exe()

time.sleep(agrd_med)

print('Abrir Plano \n')
pag.click(x=1570, y=57, clicks=1)
time.sleep(5)

print('Área de Trabalho \n')
pag.click(x=186, y=109, clicks=1)
time.sleep(agrd_crt)

print('Template_EasyMedia4 \n')
pag.click(x=86, y=182, clicks=2)
time.sleep(agrd_crt)

#Escolha Template
# Lista Templates Localização

rjbl01horpt01 = [61, 219, 'BL01hh_RJ Template 05-05  part-01']
rjbl01horpt02 = [48, 235, 'BL01hh_RJ Template 05-05  part-02']
rjbl01horpt03 = [116, 256, 'BL01hh_RJ Template 05-05  part-03']
rjbl30minpt01 = [48, 345, 'BL30m_RJ Template 05-05 part-01']
rjbl30minpt02 = [58, 363, 'BL30m_RJ Template 05-05 part-02']
rjbl30minpt03 = [126, 379, 'BL30m_RJ Template 05-05 part-03']
rjbl30minpt04 = [107, 399, 'BL30m_RJ Template 05-05 part-04']
rjbl30minpt05 = [112, 416, 'BL30m_RJ Template 05-05 part-05']

templates = [#rjbl01horpt01,
             #rjbl01horpt02,
             #rjbl01horpt03,
             #rjbl30minpt01,
             rjbl30minpt02,
             rjbl30minpt03,
             rjbl30minpt04,
             rjbl30minpt05
            ]

periodo = ['NOV/2022 A JAN/2023']

time.sleep(2)

for template in templates:
    print('Executando Template ' + str(template[2]))
    print('Aguarde 30 segundos \n')
    
    pag.click(x=template[0], y=template[1], clicks=2)
    time.sleep(agrd_med)

    time.sleep(2)
    for prd in periodo:
        print(f'Iniciando processo {prd}')
        h2 = datetime.today()
        dd2 = h2.strftime('%d-%m-%Y  %H:%M:%S')
        print(f'Horário {dd2}\n')
        
        time.sleep(2)
        print('Selecione Período \n')
        pag.click(x=1572, y=170, clicks=2)
        time.sleep(3)
        print('Selecione Filtro \n')
        pag.click(x=1621, y=464, clicks=1)
        time.sleep(2)
        # Definir período
        pag.write(prd)
        # pag.hotkey('ctrl', 'v')
        time.sleep(agrd_crt)

        pag.press('enter')
        time.sleep(agrd_crt)

        #break

        pag.click(x=1556, y=539, clicks=2)
        time.sleep(agrd_crt)

        pag.click(x=284, y=242, clicks=2)
        time.sleep(agrd_crt)

        print('Gerando Dados. Aguarde 3 minutos...\n')
        pag.click(x=37, y=111, clicks=2)
        time.sleep(60)
        print('Gerando Dados. Aguarde 2 minutos...\n')
        time.sleep(60)
        print('Gerando Dados. Aguarde 1 minutos...\n')
        time.sleep(60)
        print('Gerando Dados. Aguarde alguns segundos...\n')

        print('Salvar em CSV. Aguarde 1 minuto\n')
        pag.click(x=134, y=110, clicks=1)
        time.sleep(60)

    #Salvar CSV na pasta Download
        time.sleep(agrd_crt)
        pag.hotkey('ctrl','shift', 's')

        for x in range(7):
            pag.press('tab')
            time.sleep(1)

        pag.press('enter')
        pc.copy(r'C:\Users\pedro.sousa\Downloads')
        pag.hotkey('ctrl', 'v')
        pag.press('enter')

        for x1 in range(3):
            pag.press('enter')
            time.sleep(2)

        #Seleção
        pag.hotkey('alt','F4')
        time.sleep(2)
        pag.click(x=1845, y=111, clicks=1)
        
    
    # Retorno de tela
    pag.click(x=1821, y=107, clicks=1)
    time.sleep(agrd_crt)
    h3 = datetime.today()
    ht = (h3 - h2)
    #dd3 = h3.strftime('%H:%M:%S')
    print(f'Fim da tratativa: {prd} duração de {ht} \n')
    #print()
    est = len(templates) * ht
    print(f'A estimativa será de conclusão do Tempo Total: {est} \n')
    
    print('Abrir Plano \n')
    pag.click(x=1570, y=57, clicks=1)
    time.sleep(5)
    
    
h4 = datetime.today()
htt = (h4 - h1)
print(f'Tempo Total {htt} \n')
hf = datetime.today()
ddf = hf.strftime('%d-%m-%Y  %H:%M:%S')
print(f'Encerramento da automação dos dados: {ddf} \n')
pag.hotkey('win', 'l')

#for i in range(6):
    #pag.hotkey('alt', 'F4')
    #time.sleep(1)
    #pag.press('tab')
    #time.sleep(1)
    #pag.press('enter')
# Out:
# Início da tratativa dos dados: 14-02-2023  12:26:08
#
# Abrir Plano
#
# Área de Trabalho
#
# Template_EasyMedia4
#
# Executando Template BL30m_RJ Template 05-05 part-02
# Aguarde 30 segundos
#
# Iniciando processo NOV/2022 A JAN/2023
# Horário 14-02-2023  12:27:36
#
# Selecione Período
#
# Selecione Filtro
#
# Gerando Dados. Aguarde 3 minutos...
#
# Gerando Dados. Aguarde 2 minutos...
#
# Gerando Dados. Aguarde 1 minutos...
#
# Gerando Dados. Aguarde alguns segundos...
#
# Salvar em CSV. Aguarde 1 minuto
#
# Fim da tratativa: NOV/2022 A JAN/2023 duração de 0:05:05.287196
#
# A estimativa será de conclusão do Tempo Total: 0:20:21.148784
#
# Abrir Plano
#
# Executando Template BL30m_RJ Template 05-05 part-03
# Aguarde 30 segundos
#
# Iniciando processo NOV/2022 A JAN/2023
# Horário 14-02-2023  12:33:21
#
# Selecione Período
#
# Selecione Filtro
#
# Gerando Dados. Aguarde 3 minutos...
#
# Gerando Dados. Aguarde 2 minutos...
#
# Gerando Dados. Aguarde 1 minutos...
#
# Gerando Dados. Aguarde alguns segundos...
#
# Salvar em CSV. Aguarde 1 minuto
#
# Fim da tratativa: NOV/2022 A JAN/2023 duração de 0:05:05.326002
#
# A estimativa será de conclusão do Tempo Total: 0:20:21.304008
#
# Abrir Plano
#
# Executando Template BL30m_RJ Template 05-05 part-04
# Aguarde 30 segundos
#
# Iniciando processo NOV/2022 A JAN/2023
# Horário 14-02-2023  12:39:05
#
# Selecione Período
#
# Selecione Filtro
#
# Gerando Dados. Aguarde 3 minutos...
#
# Gerando Dados. Aguarde 2 minutos...
#
# Gerando Dados. Aguarde 1 minutos...
#
# Gerando Dados. Aguarde alguns segundos...
#
# Salvar em CSV. Aguarde 1 minuto
#
# Fim da tratativa: NOV/2022 A JAN/2023 duração de 0:05:05.314757
#
# A estimativa será de conclusão do Tempo Total: 0:20:21.259028
#
# Abrir Plano
#
# Executando Template BL30m_RJ Template 05-05 part-05
# Aguarde 30 segundos
#
# Iniciando processo NOV/2022 A JAN/2023
# Horário 14-02-2023  12:44:49
#
# Selecione Período
#
# Selecione Filtro
#
# Gerando Dados. Aguarde 3 minutos...
#
# Gerando Dados. Aguarde 2 minutos...
#
# Gerando Dados. Aguarde 1 minutos...
#
# Gerando Dados. Aguarde alguns segundos...
#
# Salvar em CSV. Aguarde 1 minuto
#
# Fim da tratativa: NOV/2022 A JAN/2023 duração de 0:05:05.299242
#
# A estimativa será de conclusão do Tempo Total: 0:20:21.196968
#
# Abrir Plano
#
# Tempo Total 0:23:52.485483
#
# Encerramento da automação dos dados: 14-02-2023  12:50:01
