# %%
import pyautogui as pag
import pyperclip as pc
import time
from datetime import datetime

pag.PAUSE = 1
agrd_crt = 3
agrd_med = 30

h1 = datetime.today()
dd1 = h1.strftime('%d-%m-%Y  %H:%M:%S')
print('inicio da tratativa dos dados:')
print(dd1)
print()




time.sleep(agrd_crt)



time.sleep(agrd_crt)

pag.hotkey("win", "r")
pc.copy("C:\IBOPE\EasyMedia 4\esm.EasyMedia4.exe")
pag.hotkey("ctrl", "v")
pag.press("enter")

time.sleep(agrd_med)


# Acesso a Template da tabela BL01hh_DF Template 05-05  part-02
#Abrir Plano
pag.click(x=1515, y=68, clicks=1)
time.sleep(agrd_crt)

#Área de Trabalho
pag.click(x=186, y=109, clicks=1)
time.sleep(agrd_crt)

#Template_EasyMedia4
pag.click(x=86, y=182, clicks=2)
time.sleep(agrd_crt)

#Escolha Template
print("Excutando Template")
print("Aguarde 30 segundos ")
print()
pag.click(x=178, y=238, clicks=2)
time.sleep(agrd_med)

periodo = ["NOV/2019 A JAN/2020",
           "DEZ/2019 A FEV/2020",
           "JAN/2020 A MAR/2020",
           "FEV/2020 A ABR/2020", 
           "MAR/2020 A MAI/2020", 
           "ABR/2020 A JUN/2020", 
           "MAI/2020 A JUL/2020", 
           "JUN/2020 A AGO/2020", 
           "JUL/2020 A SET/2020", 
           "AGO/2020 A OUT/2020", 
           "SET/2020 A NOV/2020", 
           "OUT/2020 A DEZ/2020"]    




time.sleep(2)
for prd in periodo:
    print("Iniciando processo " + prd)
    h2 = datetime.today()
    dd2 = h2.strftime('%d-%m-%Y  %H:%M:%S')
    print('Horário ')
    print(dd2)
    print()
    
    
    pag.click(x=1517, y=169, clicks=2)
    time.sleep(3)
    pag.click(x=1519, y=464, clicks=1)
    time.sleep(3)

    #time.sleep(3)
    #pag.hotkey("tab")
    #time.sleep(3)
    #pag.hotkey("tab")
    #for x in range(2):
        #pag.hotkey("tab")
        #time.sleep(2)

    time.sleep(2)
    # Definir período
    pag.write(prd)
    # pag.hotkey("ctrl", "v")
    time.sleep(agrd_crt)

    pag.press("enter")
    time.sleep(agrd_crt)
    
    #break
    
    pag.click(x=1556, y=539, clicks=2)
    time.sleep(agrd_crt)

    pag.click(x=284, y=242, clicks=2)
    time.sleep(agrd_crt)

    print("Gerando Dados ")
    print("Aguarde 3 minutos ")
    print()
    pag.click(x=37, y=111, clicks=2)
    time.sleep(180)

    print("Salvar em CSV")
    print("Aguarde 1 minuto ")
    print()
    pag.click(x=134, y=110, clicks=1)
    time.sleep(60)
    
#Salvar CSV na pasta Download
    time.sleep(agrd_crt)
    pag.hotkey("ctrl","shift", "s")

    for x in range(7):
        pag.press("tab")
        time.sleep(1)

    pag.press("enter")
    pc.copy(r"C:\Users\pedro.sousa\Downloads")
    pag.hotkey("ctrl", "v")
    pag.press("enter")

    for x1 in range(3):
        pag.press("enter")
        time.sleep(2)

    pag.hotkey("alt", "F4")
    print("Fim da Automação " + prd)
    print()
    
# Retorno de tela
    pag.click(x=1821, y=107, clicks=1)
    time.sleep(agrd_crt)
    h3 = datetime.today()
    ht = (h3 - h2)
    #dd3 = h3.strftime('%H:%M:%S')
    print('Fim da tratativa: ' + prd + " duração de ")
    print(ht)
    print()
    est = len(periodo) * ht
    print("A estimativa será de conclusão do Tempo Total: ")
    print(est)
    print()
    
    
h4 = datetime.today()
htt = (h4 - h1)
print("Tempo Total ")
print(htt)
print()

hf = datetime.today()
ddf = hf.strftime('%d-%m-%Y  %H:%M:%S')
print('Encerramento da automação dos dados:')
print(ddf)
print()
pag.hotkey("alt", "F4")
time.sleep(1)
pag.press("tab")
time.sleep(1)
pag.press("enter")
# Out:
# inicio da tratativa dos dados:
# 16-01-2023  09:49:57
#
# Excutando Template
# Aguarde 30 segundos
#
# Iniciando processo NOV/2019 A JAN/2020
# Horário
# 16-01-2023  09:51:21
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação NOV/2019 A JAN/2020
#
# Fim da tratativa: NOV/2019 A JAN/2020 duração de
# 0:05:03.573253
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:42.879036
#
# Iniciando processo DEZ/2019 A FEV/2020
# Horário
# 16-01-2023  09:56:25
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação DEZ/2019 A FEV/2020
#
# Fim da tratativa: DEZ/2019 A FEV/2020 duração de
# 0:05:03.535874
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:42.430488
#
# Iniciando processo JAN/2020 A MAR/2020
# Horário
# 16-01-2023  10:01:28
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação JAN/2020 A MAR/2020
#
# Fim da tratativa: JAN/2020 A MAR/2020 duração de
# 0:05:03.541527
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:42.498324
#
# Iniciando processo FEV/2020 A ABR/2020
# Horário
# 16-01-2023  10:06:32
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação FEV/2020 A ABR/2020
#
# Fim da tratativa: FEV/2020 A ABR/2020 duração de
# 0:05:03.613082
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:43.356984
#
# Iniciando processo MAR/2020 A MAI/2020
# Horário
# 16-01-2023  10:11:35
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação MAR/2020 A MAI/2020
#
# Fim da tratativa: MAR/2020 A MAI/2020 duração de
# 0:05:03.522840
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:42.274080
#
# Iniciando processo ABR/2020 A JUN/2020
# Horário
# 16-01-2023  10:16:39
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação ABR/2020 A JUN/2020
#
# Fim da tratativa: ABR/2020 A JUN/2020 duração de
# 0:05:03.615883
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:43.390596
#
# Iniciando processo MAI/2020 A JUL/2020
# Horário
# 16-01-2023  10:21:42
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação MAI/2020 A JUL/2020
#
# Fim da tratativa: MAI/2020 A JUL/2020 duração de
# 0:05:03.755120
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:45.061440
#
# Iniciando processo JUN/2020 A AGO/2020
# Horário
# 16-01-2023  10:26:46
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação JUN/2020 A AGO/2020
#
# Fim da tratativa: JUN/2020 A AGO/2020 duração de
# 0:05:03.560806
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:42.729672
#
# Iniciando processo JUL/2020 A SET/2020
# Horário
# 16-01-2023  10:31:50
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação JUL/2020 A SET/2020
#
# Fim da tratativa: JUL/2020 A SET/2020 duração de
# 0:05:03.571890
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:42.862680
#
# Iniciando processo AGO/2020 A OUT/2020
# Horário
# 16-01-2023  10:36:53
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação AGO/2020 A OUT/2020
#
# Fim da tratativa: AGO/2020 A OUT/2020 duração de
# 0:05:03.558732
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:42.704784
#
# Iniciando processo SET/2020 A NOV/2020
# Horário
# 16-01-2023  10:41:57
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação SET/2020 A NOV/2020
#
# Fim da tratativa: SET/2020 A NOV/2020 duração de
# 0:05:03.515394
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:42.184728
#
# Iniciando processo OUT/2020 A DEZ/2020
# Horário
# 16-01-2023  10:47:00
#
# Gerando Dados
# Aguarde 3 minutos
#
# Salvar em CSV
# Aguarde 1 minuto
#
# Fim da Automação OUT/2020 A DEZ/2020
#
# Fim da tratativa: OUT/2020 A DEZ/2020 duração de
# 0:05:03.602212
#
# A estimativa será de conclusão do Tempo Total:
# 1:00:43.226544
#
# Tempo Total
# 1:02:07.128454
#
# Encerramento da automação dos dados:
# 16-01-2023  10:52:04
